# %%
import numpy as np
def eval_classifier(h, D):
    test_X, test_y = D
    return score(h, test_X, test_y)

# %% [markdown]
# # 1 Evaluating a classifier
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Answer
# Percy proposal would overfitting illusion.  it return 1 because the model has already seen the dataset. giving it the illusion of over estimate it cabability.
# May be randomly select subset of training data to test, and the other to evaluate the performance.  The output range would be [0,1].  I would give a similar score.

# %% [markdown]
# # 2 Evaluating a learning algorthm
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Answer
# It would not return the same classifier.  Even if it is in the same distribution.  Since sampling introduce randomness.  Individual examples seen by L will differ, so learned parameters or decision boundaries will vary.
# And Model senitivity to intialization, training dynamics and data ordering.  Even small differences in training data can lead to diverging outcomes.
# Regularization and Stochasticity would further amplifying divergence.
#
# When we say that Data are drawn from the same distribution, it mean:
# The underlying data-generating process is identical.
# Each datapoint in both datasets is sampled independently and identically.
# That mean that the statistical properties like mean , variance, class balance, feature correlations, should align across both datasets.
#
# ## Why same distribution is importance in Machine Learning.
# 1. It allow Estimate generalization.
#     - If it perform well on new samples from same distribution, you can trust its predictive power
# 2. Justify cross-validation and training/ test splits:
# 3. Use probabilistic bound
